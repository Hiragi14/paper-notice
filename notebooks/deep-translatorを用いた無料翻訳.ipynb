# %%
from deep_translator import GoogleTranslator


# 翻訳インスタンスの作成（英語から日本語へ）
translator = GoogleTranslator(source='en', target='ja')
japanese_text = translator.translate('Hello, how are you?')
print(japanese_text)  # こんにちは、お元気ですか？
# Out:
# こんにちは お元気ですか？
